# %%
#import numpy as np
import pandas as pd

# %%
a=[4, 7, -5, 3]    # List
a
# Out:
# [4, 7, -5, 3]

# %%
a1=np.array([4, 7, -5, 3])
a1
# Out:
# array([ 4,  7, -5,  3])

# %%
a2 = pd.Series([4, 2, -5, 3])
a2
# Out:
# 0    4
# 1    2
# 2   -5
# 3    3
# dtype: int64

# %%
a2.dtype
# Out:
# dtype('int64')

# %%
a2.values          # Return in numpy array.
# Out:
# array([ 4,  2, -5,  3])

# %%
print(a2.values)   # Return in numpy array.
# Out:
# [ 4  2 -5  3]

# %%
a2.index     # Stop index is exclusive.
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
obj2 = pd.Series([4, 7, -5, "Hussain"], index=[1,2.5,3,'Ali'])        # Index must be equal to values present in Series
obj2
# Out:
# 1            4
# 2.5          7
# 3           -5
# Ali    Hussain
# dtype: object

# %%
obj2[2.5]
# Out:
# 7

# %%
obj2.index
# Out:
# Index([1, 2.5, 3, 'Ali'], dtype='object')

# %%
obj2[2.5]= 0

# %%
obj2
# Out:
# 1            4
# 2.5          0
# 3           -5
# Ali    Hussain
# dtype: object

# %%
obj2[obj2 == 'Hussain' ]
# Out:
# Ali    Hussain
# dtype: object

# %%
obj2 == 'Hussain'
# Out:
# 1      False
# 2.5    False
# 3      False
# Ali     True
# dtype: bool

# %%
'Ali' in obj2     # in operator applies on indexes not on values.
# Out:
# True

# %%
'Hussain' in obj2
# Out:
# False

# %%
sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}   # Dict= {Key:value}
sdata
# Out:
# {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}

# %%
obj3 = pd.Series(sdata)
obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
'Ohio' in obj3    # Points out the presence of value.
# Out:
# True

# %%
obj3['Texas']     # Return the exect value.
# Out:
# 71000

# %%
states = ['California', 'Ohio', 'Oregon', 'Texas']
states
# Out:
# ['California', 'Ohio', 'Oregon', 'Texas']

# %%
obj4 = pd.Series(sdata, index=states)   # var= pd.Series(data,index)
obj4
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
obj4.astype('int64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-cecdfbe67fcd> in <module>
# ----> 1 obj4.astype('int64')
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5546         else:
#    5547             # else, only a single dtype is given
# -> 5548             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5549             return self._constructor(new_data).__finalize__(self, method="astype")
#    5550
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     602         self, dtype, copy: bool = False, errors: str = "raise"
#     603     ) -> "BlockManager":
# --> 604         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     605
#     606     def convert(
#
# ...

# %%
pd.isnull(obj4)
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
pd.notnull(obj4)
# Out:
# California    False
# Ohio           True
# Oregon         True
# Texas          True
# dtype: bool

# %%
result = obj3 + obj4    5000+NaN=  NaN        ,4+4=8
result
# Out:
# California         NaN
# Ohio           70000.0
# Oregon         32000.0
# Texas         142000.0
# Utah               NaN
# dtype: float64

# %%
obj4.name = 'population'

# %%
obj4.index.name = 'state'

# %%
obj4.index = ['Bob', 'Steve', 'Jeff', 'Ryan']

# %%
obj4
# Out:
# Bob          NaN
# Steve    35000.0
# Jeff     16000.0
# Ryan     71000.0
# Name: population, dtype: float64
